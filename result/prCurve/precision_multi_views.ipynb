# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# draw the picture
def draw(baseline_merge, topic_day, topic_location, context_day, context_location, filename):

    plt.figure(figsize=(8, 7))

    baseline_merge,   = plt.plot(baseline_merge[0], baseline_merge[1],     'k', linewidth=4)
    topic_day,        = plt.plot(topic_day[0], topic_day[1],     'r--', linewidth=4)
    topic_location,   = plt.plot(topic_location[0], topic_location[1], 'g--', linewidth=4)
    context_day,      = plt.plot(context_day[0], context_day[1],   'r', linewidth=4)
    context_location, = plt.plot(context_location[0], context_location[1], 'g', linewidth=4)
    
    # set X axis
    plt.xlim( [0, 5200] )
    plt.xticks( np.linspace(0, 5000, 6), size=15)
    plt.xlabel("Top U", fontsize=20)
    
    # set Y axis
    plt.ylim( [0.45, 0.95] )
    plt.yticks( np.linspace(0.45, 0.95, 6), size=15)
    plt.ylabel("Precision",    fontsize=20)
    
    # set figure information
    # plt.title("", fontsize="x-large")
    plt.legend([baseline_merge, topic_day, topic_location, context_day, context_location], ("Baseline-Merge", "Topic-Day", 
    "Topic-Location", "Context-Day-Location", "Context-Location-Time"), loc="upper right", numpoints=1, fontsize=18)
    plt.grid(True)

    # draw the chart
    plt.savefig("./" + filename + ".pdf", format="pdf")
    plt.show()

# %%
baseline_merge = \
[(500,1000,1500,2000,2500,3000,3500,4000,4500,5000), 
 (0.944,0.815,0.725,0.663,0.621,0.584,0.555,0.535,0.516,0.502) ]

topic_day = \
[(500,1000,1500,2000,2500,3000,3500,4000,4500,5000),
 (0.811,0.738,0.680,0.639,0.616,0.596,0.575,0.551,0.527,0.506) ]

topic_location = \
[(500,1000,1500,2000,2500,3000,3500,4000,4500,5000),
 (0.858,0.766,0.712,0.670,0.628,0.599,0.572,0.549,0.523,0.507)]

context_day = \
[(500,1000,1500,2000,2500,3000,3500,4000,4500,5000),
 (0.827,0.777,0.732,0.685,0.649,0.619,0.586,0.559,0.534,0.509) ]

context_location = \
[(500,1000,1500,2000,2500,3000,3500,4000,4500,5000),
 (0.879,0.808,0.745,0.692,0.656,0.621,0.587,0.559,0.532,0.508)]

draw(baseline_merge, topic_day, topic_location, context_day, context_location, "Gowalla_precision_multi_views")
